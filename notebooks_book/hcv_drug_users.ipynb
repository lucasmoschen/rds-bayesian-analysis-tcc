# %% [markdown]
# # HCV Drug Users Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_hcv = pd.read_csv('../data/HCV_drug_users/41598_2018_35657_MOESM2_ESM.csv', sep = ';', index_col = 0)
df_hcv.head()
# Out:
#    HCV  Par  semana_new  turno_new  IDU  Polydrug  GenitalUlcers
# 3    1   89           2          2    0         0              0
# 5    0   79           1          2    0         0              0
# 6    0   80           2          2    0         0              0
# 7    0  116           1          1    0         0              0
# 8    0  103           1          1    0         0              0

# %%
df_hcv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 632 entries, 3 to 645
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HCV            632 non-null    int64
#  1   Par            632 non-null    int64
#  2   semana_new     632 non-null    int64
#  3   turno_new      632 non-null    int64
#  4   IDU            632 non-null    int64
#  5   Polydrug       632 non-null    int64
#  6   GenitalUlcers  632 non-null    int64
# dtypes: int64(7)
# memory usage: 39.5 KB

# %%
df_hcv.HCV.value_counts()
# Out:
# 0    506
# 1    126
# Name: HCV, dtype: int64

# %%
df_hcv.Par.plot.hist(bins = 30)
plt.show()

# %%
sns.scatterplot(x=df_hcv.index, y ='Par', hue='HCV', data = df_hcv)
plt.show()

# %%
df_hcv.semana_new.value_counts()
# Out:
# 1    359
# 2    273
# Name: semana_new, dtype: int64

# %%
df_hcv.turno_new.value_counts()
# Out:
# 1    385
# 2    247
# Name: turno_new, dtype: int64
